# %%
from scipy.stats import uniform, expon, randint, loguniform, truncexpon
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
r = uniform.rvs(loc=0.2, scale=0.8-0.2,size=10000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
r.min(), r.max()
# Out:
# (0.20002171212257613, 0.7999381090208955)

# %%
r = expon.rvs(loc=0.01, scale=0.1,size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np

# %%
r = np.random.exponential(scale=2,size=1).astype('int') + 5
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
r
# Out:
# No handles with labels found to put in legend.
# array([8])

# %%
r = np.random.exponential(size=10).astype('int') + 5
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
r
# Out:
# array([5, 5, 6, 5, 5, 6, 7, 5, 5, 5])

# %%
r = loguniform.rvs(a=0.001, b=0.1, size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
r = randint.rvs(low=0, high=20, size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
r = truncexpon.rvs(loc=0.01, b=1-0.01, size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
plt.show()

# %%
r.min(), r.max()
# Out:
# (0.01002975225792949, 0.9992317460100815)

# %%
r = loguniform.rvs(a=0.01, b=1, size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
r = uniform.rvs(loc=0.01, scale=1-0.01, size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# No handles with labels found to put in legend.
