# %%
# %load_ext line_profiler

# %%
from sir_model_func_rev1 import sir_model
import pandas as pd
import numpy as np

# %%
OD = np.load("/Users/agm/Documents/KSchool/TFM/data_out/od_matrix.npy")
df = pd.read_pickle(
    "/Users/agm/Documents/KSchool/TFM/data_out/fulldataset_agm_rev1.gpickle")

# %%
a = 0.6
int(a)
# Out:
# 0

# %%
R0_g = 2.5 # valor de R0
Tr_g = 15 # fijo el valor de tiempo de recuperación
Tc_g = np.divide(Tr_g, R0_g)
omega_g = 0.01
initial_country = 'CHN'
T = 1000
initial_infected = 1

# %lprun -f sir_model sir_model(df, OD, Tc_g, Tr_g, omega_g, initial_country, initial_infected, T)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.761452 s
# File: /Users/agm/Documents/kschool/TFM/sir_model_func_rev1.py
# Function: sir_model at line 14
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     14                                           def sir_model(df, OD, Tc, Tr, omega, initial_country, initial_infected, T):
#     15
#     16                                               """
#     17
#     18                                               Simulates a SIR model. There is a SIR model for each country that interact
#     19                                               with each other.
#     20
#     21                                               Params
#     22                                               -----------
#     23                                               df: Dataframe
#     24                                               Dataframe with information about countries
# ...
